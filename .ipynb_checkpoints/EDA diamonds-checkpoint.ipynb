# %%
import pandas as pd

# %%
df=pd.read_csv('data/diamonds_final.csv')
df.head()
# Out:
#                                              city_id       city  \
# 0  0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...  Amsterdam
# 1  0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...  Amsterdam
# 2  0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...  Amsterdam
# 3  0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...  Amsterdam
# 4  0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...  Amsterdam
#
#                                             index_id  price  carat  \
# 0  5f9c4ab08cac7457e9111a30e4664920607ea2c115a143...   6216   1.00
# 1  624b60c58c9d8bfb6ff1886c2fd605d2adeb6ea4da5760...   4969   1.16
# 2  86e50149658661312a9e0b35558d84f6c6d3da797f552a...   2422   0.70
# 3  3d914f9348c9cc0ff8a79716700b9fcd4d2f3e71160800...   3861   1.04
# 4  8722616204217eddb39e7df969e0698aed8e599ba62ed2...   2440   0.78
#
#                                           clarity_id clarity  \
# 0  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 1  03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 2  ef736c1f91cd1900c3d9cde925b1bf4f013adc0211a9ee...     VS1
# 3  03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 4  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
#
#                                               cut_id  \
# 0  de88c121a82a06352bf1aaceba20578356408a334ba046...
# 1  de88c121a82a06352bf1aaceba20578356408a334ba046...
# 2  388655e25e91872329272fc10128ef5354b3b19a05d7e8...
# 3  de88c121a82a06352bf1aaceba20578356408a334ba046...
# 4  c939327ca16dcf97ca32521d8b834bf1de16573d21deda...
#
#                                             color_id color        cut  depth  \
# 0  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G    Premium   61.6
# 1  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G    Premium   62.5
# 2  44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...     H  Very Good   62.1
# 3  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G    Premium   62.2
# 4  44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...     H       Good   63.7
#
#    table     x     y     z
# 0   54.0  6.49  6.46  3.99
# 1   58.0  6.72  6.68  4.19
# 2   56.0  5.65  5.68  3.52
# 3   59.0  6.57  6.49  4.06
# 4   60.0  5.77  5.73  3.66

# %%
#checking for null values
df.isnull().sum()
# Out:
# city_id       0
# city          0
# index_id      0
# price         0
# carat         0
# clarity_id    0
# clarity       0
# cut_id        0
# color_id      0
# color         0
# cut           0
# depth         0
# table         0
# x             0
# y             0
# z             0
# dtype: int64

# %%
#checking for null values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40455 entries, 0 to 40454
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   city_id     40455 non-null  object
#  1   city        40455 non-null  object
#  2   index_id    40455 non-null  object
#  3   price       40455 non-null  int64
#  4   carat       40455 non-null  float64
#  5   clarity_id  40455 non-null  object
#  6   clarity     40455 non-null  object
#  7   cut_id      40455 non-null  object
#  8   color_id    40455 non-null  object
#  9   color       40455 non-null  object
#  10  cut         40455 non-null  object
#  11  depth       40455 non-null  float64
#  12  table       40455 non-null  float64
#  13  x           40455 non-null  float64
#  14  y           40455 non-null  float64
#  15  z           40455 non-null  float64
# dtypes: float64(6), int64(1), object(9)
# memory usage: 4.9+ MB

# %%
df.head()
# Out:
#                                              city_id       city  \
# 0  0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...  Amsterdam
# 1  0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...  Amsterdam
# 2  0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...  Amsterdam
# 3  0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...  Amsterdam
# 4  0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...  Amsterdam
#
#                                             index_id  price  carat  \
# 0  5f9c4ab08cac7457e9111a30e4664920607ea2c115a143...   6216   1.00
# 1  624b60c58c9d8bfb6ff1886c2fd605d2adeb6ea4da5760...   4969   1.16
# 2  86e50149658661312a9e0b35558d84f6c6d3da797f552a...   2422   0.70
# 3  3d914f9348c9cc0ff8a79716700b9fcd4d2f3e71160800...   3861   1.04
# 4  8722616204217eddb39e7df969e0698aed8e599ba62ed2...   2440   0.78
#
#                                           clarity_id clarity  \
# 0  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 1  03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 2  ef736c1f91cd1900c3d9cde925b1bf4f013adc0211a9ee...     VS1
# 3  03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 4  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
#
#                                               cut_id  \
# 0  de88c121a82a06352bf1aaceba20578356408a334ba046...
# 1  de88c121a82a06352bf1aaceba20578356408a334ba046...
# 2  388655e25e91872329272fc10128ef5354b3b19a05d7e8...
# 3  de88c121a82a06352bf1aaceba20578356408a334ba046...
# 4  c939327ca16dcf97ca32521d8b834bf1de16573d21deda...
#
#                                             color_id color        cut  depth  \
# 0  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G    Premium   61.6
# 1  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G    Premium   62.5
# 2  44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...     H  Very Good   62.1
# 3  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G    Premium   62.2
# 4  44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...     H       Good   63.7
#
#    table     x     y     z
# 0   54.0  6.49  6.46  3.99
# 1   58.0  6.72  6.68  4.19
# 2   56.0  5.65  5.68  3.52
# 3   59.0  6.57  6.49  4.06
# 4   60.0  5.77  5.73  3.66

# %%
df=df.drop(labels=['index_id'],axis=1)
df.head()
# Out:
#                                              city_id       city  price  carat  \
# 0  0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...  Amsterdam   6216   1.00
# 1  0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...  Amsterdam   4969   1.16
# 2  0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...  Amsterdam   2422   0.70
# 3  0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...  Amsterdam   3861   1.04
# 4  0013c01fe0d094209b8bd3d23b8f96dbabcd01ddd2a039...  Amsterdam   2440   0.78
#
#                                           clarity_id clarity  \
# 0  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
# 1  03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 2  ef736c1f91cd1900c3d9cde925b1bf4f013adc0211a9ee...     VS1
# 3  03c358cbd92e83278fd523f58dc6a9b4b198d00728af65...     SI2
# 4  f0b2a1d0db08cc64f85d74f1d15c2191e0e49039f4d8f2...     VS2
#
#                                               cut_id  \
# 0  de88c121a82a06352bf1aaceba20578356408a334ba046...
# 1  de88c121a82a06352bf1aaceba20578356408a334ba046...
# 2  388655e25e91872329272fc10128ef5354b3b19a05d7e8...
# 3  de88c121a82a06352bf1aaceba20578356408a334ba046...
# 4  c939327ca16dcf97ca32521d8b834bf1de16573d21deda...
#
#                                             color_id color        cut  depth  \
# 0  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G    Premium   61.6
# 1  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G    Premium   62.5
# 2  44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...     H  Very Good   62.1
# 3  333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...     G    Premium   62.2
# 4  44bd7ae60f478fae1061e11a7739f4b94d1daf917982d3...     H       Good   63.7
#
#    table     x     y     z
# 0   54.0  6.49  6.46  3.99
# 1   58.0  6.72  6.68  4.19
# 2   56.0  5.65  5.68  3.52
# 3   59.0  6.57  6.49  4.06
# 4   60.0  5.77  5.73  3.66

# %%
numerical_columns=df.columns[df.dtypes!='object']
categorical_columns=df.columns[df.dtypes=='object']
print("Numerical columns:",numerical_columns)
print('Categorical Columns:',categorical_columns)
# Out:
# Numerical columns: Index(['price', 'carat', 'depth', 'table', 'x', 'y', 'z'], dtype='object')
# Categorical Columns: Index(['city_id', 'city', 'clarity_id', 'clarity', 'cut_id', 'color_id',
#        'color', 'cut'],
#       dtype='object')

# %%
df[categorical_columns].describe()
# Out:
#                                                   city_id     city  \
# count                                               40455    40455
# unique                                                 13       13
# top     ca3aa21a5b70c3e88cc6336682c8c7da928a0c66a5ead4...  Antwerp
# freq                                                 5062     5062
#
#                                                clarity_id clarity  \
# count                                               40455   40455
# unique                                                  8       8
# top     bd4f4a250da88f87729febc739ae97f439a14f9d38f0e3...     SI1
# freq                                                 9749    9749
#
#                                                    cut_id  \
# count                                               40455
# unique                                                  5
# top     4e3cfaa334cbafb57a399a98fad8d3812ece460018f457...
# freq                                                16220
#
#                                                  color_id  color    cut
# count                                               40455  40455  40455
# unique                                                  7      7      5
# top     333e0a1e27815d0ceee55c473fe3dc93d56c63e3bee2b3...      G  Ideal
# freq                                                 8455   8455  16220

# %%
df['cut'].value_counts()
# Out:
# cut
# Ideal        16220
# Premium      10260
# Very Good     9095
# Good          3663
# Fair          1217
# Name: count, dtype: int64

# %%
df['color'].value_counts()
# Out:
# color
# G    8455
# E    7325
# F    7177
# H    6277
# D    5049
# I    4032
# J    2140
# Name: count, dtype: int64

# %%
df['clarity'].value_counts()
# Out:
# clarity
# SI1     9749
# VS2     9248
# SI2     6929
# VS1     6066
# VVS2    3799
# VVS1    2774
# IF      1327
# I1       563
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
x=0
for i in numerical_columns:
    sns.histplot(data=df,x=i,kde=True)
    print('\n')
    plt.show()
# Out:
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(8,6))
x=0
for i in categorical_columns:
    sns.catplot(data=df,x=i)
    print('\n')
    plt.show()
# Out:
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self._figure.tight_layout(*args, **kwargs)
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/nataliavargas/miniconda3/envs/m3_env/lib/python3.11/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.heatmap(df[numerical_columns].corr(),annot=True)
# Out:
# <Axes: >

# %%
df['cut'].unique()
# Out:
# array(['Premium', 'Very Good', 'Good', 'Ideal', 'Fair'], dtype=object)

# %%
cut_map={"Fair":1,"Good":2,"Very Good":3,"Premium":4,"Ideal":5}

# %%
df['clarity'].unique()
# Out:
# array(['VS2', 'SI2', 'VS1', 'SI1', 'VVS1', 'VVS2', 'IF', 'I1'],
#       dtype=object)
